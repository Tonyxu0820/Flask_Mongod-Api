# %%
import json
import pandas as pd
import requests
from pprint import pprint
from flask import Flask, render_template, request, json

app = Flask(__name__)

@app.route('/', methods=['GET', 'POST'])
def home():
    return render_template("my-form.html",query_result=[])

@app.route('/query', methods=['GET', 'POST'])
def query():
    b=request.form["BORO"]

    print(b)
    data = pd.read_csv('shooting.csv')
    data = data[(data['BORO']==request.form["BORO"]) ]
    data = data.to_dict(orient='records')
    response = json.dumps(data, indent=1)
    print(data)
    return render_template("my-form.html",query_result=data)


if __name__ == '__main__':
    app.run(host='localhost', port=5002)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:5002 (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Apr/2022 23:59:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2022 23:59:16] "GET /static/customer.css HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 23:59:16] "GET /static/index.js HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 23:59:19] "POST /query HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2022 23:59:19] "GET /static/customer.css HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 23:59:19] "GET /static/index.js HTTP/1.1" 404 -
# BROOKLYN
# ...
