# %% [markdown]
# ## Technology 1:
# ## PostgresSQL, connect through pgAdmin4, easiest way to summarize the data.

# %%
# !pip install psycopg2-binary
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\xinru\anaconda3\lib\site-packages (2.9.3)
# Requirement already satisfied: psycopg2 in c:\users\xinru\anaconda3\lib\site-packages (2.9.3)

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: ipython-sql in c:\users\xinru\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: ipython>=1.0 in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (7.29.0)
# Requirement already satisfied: prettytable<1 in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: sqlparse in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: six in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\xinru\anaconda3\lib\site-packages (from ipython-sql) (1.4.22)
# Requirement already satisfied: decorator in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (58.0.4)
# Requirement already satisfied: pickleshare in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: colorama in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.0)
# Requirement already satisfied: pygments in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.10.0)
# Requirement already satisfied: backcall in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\xinru\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\xinru\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\xinru\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\xinru\anaconda3\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Requirement already satisfied: sqlalchemy in c:\users\xinru\anaconda3\lib\site-packages (1.4.22)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\xinru\anaconda3\lib\site-packages (from sqlalchemy) (1.1.1)

# %%
import psycopg2, os

print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(
    host="localhost",
    port='5432',
    database="Shooting_Crime",
    user="postgres",
    password="123")
# Out:
# Connecting to the PostgreSQL database...

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine
# %sql postgresql://postgres:123@localhost:5432/Shooting_Crime

# %%
engine = create_engine('postgresql://postgres:password123@localhost/Shooting_Crime')

# %% [markdown]
# ### Displace number of shooting happened group by neighboor

# %%
# %%sql
#
# SELECT boro, COUNT(boro)
# FROM shooting_incident
# WHERE boro = 'BROOKLYN' OR boro = 'BRONX' OR boro = 'QUEENS' OR boro = 'MANHATTAN' OR boro = 'STATEN ISLAND'
# GROUP BY boro
# Out:
#  * postgresql://postgres:***@localhost:5432/Shooting_Crime
# 5 rows affected.
# [('MANHATTAN', 343),
#  ('BRONX', 701),
#  ('QUEENS', 296),
#  ('BROOKLYN', 631),
#  ('STATEN ISLAND', 40)]

# %% [markdown]
# ## Technology 2:
# ## MongoDB, a faster way of processing data than postgresSQL, better technique for future larger data set and data storage

# %%
#Create connection to MongoDB
# !pip3 install pymongo
from pymongo import MongoClient
client = MongoClient('localhost',27017) ## or MongoClient("localhost:27")
db = client.apan5400
# Out:
# Requirement already satisfied: pymongo in c:\users\xinru\anaconda3\lib\site-packages (4.1.1)

# %%
#Create connection to MongoDB
import requests
import json
# !pip install flask_pymongo
from flask_pymongo import PyMongo
url = "https://data.cityofnewyork.us/resource/5ucz-vwe8.json?$limit=150000"
r = requests.get(url)
json_data = json.loads(r.text)

collection = db.shooting1
collection.insert_many(json_data)
# Out:
# Requirement already satisfied: flask_pymongo in c:\users\xinru\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: PyMongo>=3.3 in c:\users\xinru\anaconda3\lib\site-packages (from flask_pymongo) (4.1.1)
# Requirement already satisfied: Flask>=0.11 in c:\users\xinru\anaconda3\lib\site-packages (from flask_pymongo) (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\xinru\anaconda3\lib\site-packages (from Flask>=0.11->flask_pymongo) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\xinru\anaconda3\lib\site-packages (from Flask>=0.11->flask_pymongo) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\xinru\anaconda3\lib\site-packages (from Flask>=0.11->flask_pymongo) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\xinru\anaconda3\lib\site-packages (from Flask>=0.11->flask_pymongo) (2.11.3)
# Requirement already satisfied: colorama in c:\users\xinru\anaconda3\lib\site-packages (from click>=5.1->Flask>=0.11->flask_pymongo) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\xinru\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.11->flask_pymongo) (1.1.1)

# %%
len(json_data)
# Out:
# 2011

# %%
collection = db.shooting
collection.insert_many(json_data)

# %% [markdown]
# ### Selecting the name of borough such as Manhattan (other areas are same as Manhattan to see the results) to see recent crime date and time in the areas.

# %%
#displace incident happen in Manhattan
pipeline = [
    { "$match": { "boro":  "MANHATTAN"} },
        { "$group":{ 
         "_id": {
             "borough": "MANHATTAN",
             "occur_date": "$occur_date",
             "occur_time": "$occur_time"}}}
]

list(db.shooting.aggregate(pipeline))
# Out:
# [{'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-03T00:00:00.000',
#    'occur_time': '22:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-21T00:00:00.000',
#    'occur_time': '02:36:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-12T00:00:00.000',
#    'occur_time': '01:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-24T00:00:00.000',
#    'occur_time': '22:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-18T00:00:00.000',
#    'occur_time': '12:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-24T00:00:00.000',
#    'occur_time': '22:09:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-12T00:00:00.000',
#    'occur_time': '17:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-09T00:00:00.000',
#    'occur_time': '12:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-18T00:00:00.000',
#    'occur_time': '19:58:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-23T00:00:00.000',
#    'occur_time': '23:18:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-20T00:00:00.000',
#    'occur_time': '22:53:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-16T00:00:00.000',
#    'occur_time': '12:39:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-04T00:00:00.000',
#    'occur_time': '07:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-29T00:00:00.000',
#    'occur_time': '23:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-04T00:00:00.000',
#    'occur_time': '22:06:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-27T00:00:00.000',
#    'occur_time': '22:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-19T00:00:00.000',
#    'occur_time': '03:12:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-03T00:00:00.000',
#    'occur_time': '02:25:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-04T00:00:00.000',
#    'occur_time': '00:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-03T00:00:00.000',
#    'occur_time': '00:01:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-11T00:00:00.000',
#    'occur_time': '20:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-31T00:00:00.000',
#    'occur_time': '03:38:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-14T00:00:00.000',
#    'occur_time': '02:28:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-23T00:00:00.000',
#    'occur_time': '13:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-18T00:00:00.000',
#    'occur_time': '00:31:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-01T00:00:00.000',
#    'occur_time': '17:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-23T00:00:00.000',
#    'occur_time': '19:41:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-15T00:00:00.000',
#    'occur_time': '20:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-10T00:00:00.000',
#    'occur_time': '07:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-25T00:00:00.000',
#    'occur_time': '16:57:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-08T00:00:00.000',
#    'occur_time': '19:08:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-28T00:00:00.000',
#    'occur_time': '20:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-08T00:00:00.000',
#    'occur_time': '23:32:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-01T00:00:00.000',
#    'occur_time': '19:39:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-31T00:00:00.000',
#    'occur_time': '01:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-23T00:00:00.000',
#    'occur_time': '09:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-09T00:00:00.000',
#    'occur_time': '16:24:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-11T00:00:00.000',
#    'occur_time': '20:20:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-24T00:00:00.000',
#    'occur_time': '05:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-15T00:00:00.000',
#    'occur_time': '20:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-02T00:00:00.000',
#    'occur_time': '02:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-06T00:00:00.000',
#    'occur_time': '02:47:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-11T00:00:00.000',
#    'occur_time': '17:53:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-09T00:00:00.000',
#    'occur_time': '04:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-28T00:00:00.000',
#    'occur_time': '22:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-29T00:00:00.000',
#    'occur_time': '23:47:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-30T00:00:00.000',
#    'occur_time': '00:52:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-22T00:00:00.000',
#    'occur_time': '20:04:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-03T00:00:00.000',
#    'occur_time': '16:02:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-27T00:00:00.000',
#    'occur_time': '19:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-13T00:00:00.000',
#    'occur_time': '00:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-24T00:00:00.000',
#    'occur_time': '00:45:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-18T00:00:00.000',
#    'occur_time': '19:41:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-19T00:00:00.000',
#    'occur_time': '01:25:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-26T00:00:00.000',
#    'occur_time': '20:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-13T00:00:00.000',
#    'occur_time': '23:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-18T00:00:00.000',
#    'occur_time': '14:18:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-15T00:00:00.000',
#    'occur_time': '01:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-27T00:00:00.000',
#    'occur_time': '05:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-26T00:00:00.000',
#    'occur_time': '21:47:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-31T00:00:00.000',
#    'occur_time': '23:53:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-18T00:00:00.000',
#    'occur_time': '20:39:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-25T00:00:00.000',
#    'occur_time': '18:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-13T00:00:00.000',
#    'occur_time': '13:56:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-09T00:00:00.000',
#    'occur_time': '17:16:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-20T00:00:00.000',
#    'occur_time': '01:21:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-16T00:00:00.000',
#    'occur_time': '14:37:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-01T00:00:00.000',
#    'occur_time': '02:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-01T00:00:00.000',
#    'occur_time': '13:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-31T00:00:00.000',
#    'occur_time': '23:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-21T00:00:00.000',
#    'occur_time': '00:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-07T00:00:00.000',
#    'occur_time': '00:38:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-31T00:00:00.000',
#    'occur_time': '22:29:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-17T00:00:00.000',
#    'occur_time': '18:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-12T00:00:00.000',
#    'occur_time': '01:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-17T00:00:00.000',
#    'occur_time': '22:28:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-17T00:00:00.000',
#    'occur_time': '14:23:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-17T00:00:00.000',
#    'occur_time': '20:37:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-10T00:00:00.000',
#    'occur_time': '23:31:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-06T00:00:00.000',
#    'occur_time': '01:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-23T00:00:00.000',
#    'occur_time': '02:16:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-25T00:00:00.000',
#    'occur_time': '20:19:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-27T00:00:00.000',
#    'occur_time': '19:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-23T00:00:00.000',
#    'occur_time': '17:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-21T00:00:00.000',
#    'occur_time': '17:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-28T00:00:00.000',
#    'occur_time': '02:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-27T00:00:00.000',
#    'occur_time': '01:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-01T00:00:00.000',
#    'occur_time': '10:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-29T00:00:00.000',
#    'occur_time': '03:56:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-06T00:00:00.000',
#    'occur_time': '01:57:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-04T00:00:00.000',
#    'occur_time': '19:57:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-05T00:00:00.000',
#    'occur_time': '04:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-15T00:00:00.000',
#    'occur_time': '22:12:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-22T00:00:00.000',
#    'occur_time': '21:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-30T00:00:00.000',
#    'occur_time': '20:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-28T00:00:00.000',
#    'occur_time': '23:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-25T00:00:00.000',
#    'occur_time': '23:16:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-23T00:00:00.000',
#    'occur_time': '23:49:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-04T00:00:00.000',
#    'occur_time': '23:23:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-12T00:00:00.000',
#    'occur_time': '07:23:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-28T00:00:00.000',
#    'occur_time': '15:45:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-11T00:00:00.000',
#    'occur_time': '01:34:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-08T00:00:00.000',
#    'occur_time': '18:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-31T00:00:00.000',
#    'occur_time': '23:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-22T00:00:00.000',
#    'occur_time': '06:32:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-27T00:00:00.000',
#    'occur_time': '03:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-27T00:00:00.000',
#    'occur_time': '20:38:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-02T00:00:00.000',
#    'occur_time': '18:18:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-17T00:00:00.000',
#    'occur_time': '04:43:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-03T00:00:00.000',
#    'occur_time': '20:01:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-10T00:00:00.000',
#    'occur_time': '15:41:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-21T00:00:00.000',
#    'occur_time': '20:56:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-23T00:00:00.000',
#    'occur_time': '21:59:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-31T00:00:00.000',
#    'occur_time': '07:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-02T00:00:00.000',
#    'occur_time': '19:59:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-06T00:00:00.000',
#    'occur_time': '04:22:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-26T00:00:00.000',
#    'occur_time': '01:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-16T00:00:00.000',
#    'occur_time': '11:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-27T00:00:00.000',
#    'occur_time': '00:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-20T00:00:00.000',
#    'occur_time': '15:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-12T00:00:00.000',
#    'occur_time': '01:16:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-28T00:00:00.000',
#    'occur_time': '20:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-15T00:00:00.000',
#    'occur_time': '23:25:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-18T00:00:00.000',
#    'occur_time': '23:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-24T00:00:00.000',
#    'occur_time': '16:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-16T00:00:00.000',
#    'occur_time': '20:58:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-16T00:00:00.000',
#    'occur_time': '09:45:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-02T00:00:00.000',
#    'occur_time': '19:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-28T00:00:00.000',
#    'occur_time': '19:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-27T00:00:00.000',
#    'occur_time': '17:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-17T00:00:00.000',
#    'occur_time': '20:59:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-19T00:00:00.000',
#    'occur_time': '22:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-14T00:00:00.000',
#    'occur_time': '10:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-26T00:00:00.000',
#    'occur_time': '15:22:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-07T00:00:00.000',
#    'occur_time': '04:20:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-29T00:00:00.000',
#    'occur_time': '19:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-26T00:00:00.000',
#    'occur_time': '01:41:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-07T00:00:00.000',
#    'occur_time': '03:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-10T00:00:00.000',
#    'occur_time': '22:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-25T00:00:00.000',
#    'occur_time': '18:16:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-20T00:00:00.000',
#    'occur_time': '17:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-30T00:00:00.000',
#    'occur_time': '14:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-20T00:00:00.000',
#    'occur_time': '15:01:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-21T00:00:00.000',
#    'occur_time': '01:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-28T00:00:00.000',
#    'occur_time': '02:56:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-30T00:00:00.000',
#    'occur_time': '23:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-17T00:00:00.000',
#    'occur_time': '21:34:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-24T00:00:00.000',
#    'occur_time': '14:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-07T00:00:00.000',
#    'occur_time': '00:32:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-10T00:00:00.000',
#    'occur_time': '00:22:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-30T00:00:00.000',
#    'occur_time': '01:42:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-14T00:00:00.000',
#    'occur_time': '09:57:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-08T00:00:00.000',
#    'occur_time': '05:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-07T00:00:00.000',
#    'occur_time': '02:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-28T00:00:00.000',
#    'occur_time': '19:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-20T00:00:00.000',
#    'occur_time': '20:28:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-06T00:00:00.000',
#    'occur_time': '20:12:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-27T00:00:00.000',
#    'occur_time': '19:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-15T00:00:00.000',
#    'occur_time': '22:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-08T00:00:00.000',
#    'occur_time': '23:37:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-28T00:00:00.000',
#    'occur_time': '23:33:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-30T00:00:00.000',
#    'occur_time': '21:06:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-19T00:00:00.000',
#    'occur_time': '23:51:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-16T00:00:00.000',
#    'occur_time': '15:59:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-18T00:00:00.000',
#    'occur_time': '04:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-14T00:00:00.000',
#    'occur_time': '13:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-09T00:00:00.000',
#    'occur_time': '19:43:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-20T00:00:00.000',
#    'occur_time': '20:48:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-07T00:00:00.000',
#    'occur_time': '23:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-24T00:00:00.000',
#    'occur_time': '10:27:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-27T00:00:00.000',
#    'occur_time': '16:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-18T00:00:00.000',
#    'occur_time': '03:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-30T00:00:00.000',
#    'occur_time': '00:33:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-30T00:00:00.000',
#    'occur_time': '13:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-07T00:00:00.000',
#    'occur_time': '21:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-13T00:00:00.000',
#    'occur_time': '15:01:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-02T00:00:00.000',
#    'occur_time': '22:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-14T00:00:00.000',
#    'occur_time': '00:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-11T00:00:00.000',
#    'occur_time': '21:45:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-30T00:00:00.000',
#    'occur_time': '10:54:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-04T00:00:00.000',
#    'occur_time': '20:18:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-13T00:00:00.000',
#    'occur_time': '18:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-21T00:00:00.000',
#    'occur_time': '01:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-06T00:00:00.000',
#    'occur_time': '23:20:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-08T00:00:00.000',
#    'occur_time': '13:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-14T00:00:00.000',
#    'occur_time': '19:41:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-19T00:00:00.000',
#    'occur_time': '18:33:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-31T00:00:00.000',
#    'occur_time': '17:37:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-11T00:00:00.000',
#    'occur_time': '01:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-14T00:00:00.000',
#    'occur_time': '18:42:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-07T00:00:00.000',
#    'occur_time': '20:49:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-13T00:00:00.000',
#    'occur_time': '22:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-24T00:00:00.000',
#    'occur_time': '00:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-01T00:00:00.000',
#    'occur_time': '01:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-13T00:00:00.000',
#    'occur_time': '00:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-04T00:00:00.000',
#    'occur_time': '13:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-08T00:00:00.000',
#    'occur_time': '21:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-19T00:00:00.000',
#    'occur_time': '01:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-05T00:00:00.000',
#    'occur_time': '23:53:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-21T00:00:00.000',
#    'occur_time': '02:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-28T00:00:00.000',
#    'occur_time': '21:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-21T00:00:00.000',
#    'occur_time': '01:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-30T00:00:00.000',
#    'occur_time': '19:19:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-12T00:00:00.000',
#    'occur_time': '08:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-24T00:00:00.000',
#    'occur_time': '22:20:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-19T00:00:00.000',
#    'occur_time': '23:22:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-16T00:00:00.000',
#    'occur_time': '22:39:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-07T00:00:00.000',
#    'occur_time': '20:57:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-27T00:00:00.000',
#    'occur_time': '18:50:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-04T00:00:00.000',
#    'occur_time': '01:38:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-08T00:00:00.000',
#    'occur_time': '09:29:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-27T00:00:00.000',
#    'occur_time': '15:09:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-26T00:00:00.000',
#    'occur_time': '02:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-26T00:00:00.000',
#    'occur_time': '14:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-09T00:00:00.000',
#    'occur_time': '20:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-26T00:00:00.000',
#    'occur_time': '20:38:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-05T00:00:00.000',
#    'occur_time': '03:58:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-25T00:00:00.000',
#    'occur_time': '19:27:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-29T00:00:00.000',
#    'occur_time': '15:32:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-13T00:00:00.000',
#    'occur_time': '23:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-06T00:00:00.000',
#    'occur_time': '20:21:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-04T00:00:00.000',
#    'occur_time': '12:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-23T00:00:00.000',
#    'occur_time': '22:13:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-31T00:00:00.000',
#    'occur_time': '03:52:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-11T00:00:00.000',
#    'occur_time': '17:19:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-03-20T00:00:00.000',
#    'occur_time': '00:19:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-21T00:00:00.000',
#    'occur_time': '04:45:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-30T00:00:00.000',
#    'occur_time': '18:35:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-20T00:00:00.000',
#    'occur_time': '17:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-06T00:00:00.000',
#    'occur_time': '18:00:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-16T00:00:00.000',
#    'occur_time': '08:33:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-01T00:00:00.000',
#    'occur_time': '23:07:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-21T00:00:00.000',
#    'occur_time': '05:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-18T00:00:00.000',
#    'occur_time': '18:17:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-11T00:00:00.000',
#    'occur_time': '14:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-10-19T00:00:00.000',
#    'occur_time': '19:25:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-16T00:00:00.000',
#    'occur_time': '19:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-19T00:00:00.000',
#    'occur_time': '21:01:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-04T00:00:00.000',
#    'occur_time': '00:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-29T00:00:00.000',
#    'occur_time': '14:20:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-26T00:00:00.000',
#    'occur_time': '16:46:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-11T00:00:00.000',
#    'occur_time': '11:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-13T00:00:00.000',
#    'occur_time': '21:10:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-05-08T00:00:00.000',
#    'occur_time': '16:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-03T00:00:00.000',
#    'occur_time': '07:02:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-07-16T00:00:00.000',
#    'occur_time': '23:09:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-12-14T00:00:00.000',
#    'occur_time': '01:14:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-11T00:00:00.000',
#    'occur_time': '20:17:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-11-27T00:00:00.000',
#    'occur_time': '16:30:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-24T00:00:00.000',
#    'occur_time': '13:25:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-09-20T00:00:00.000',
#    'occur_time': '04:05:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-01T00:00:00.000',
#    'occur_time': '01:15:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-28T00:00:00.000',
#    'occur_time': '23:40:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-29T00:00:00.000',
#    'occur_time': '21:43:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-02-22T00:00:00.000',
#    'occur_time': '00:18:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-08-27T00:00:00.000',
#    'occur_time': '00:06:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-31T00:00:00.000',
#    'occur_time': '21:53:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-13T00:00:00.000',
#    'occur_time': '02:55:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-01-26T00:00:00.000',
#    'occur_time': '09:03:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-06-08T00:00:00.000',
#    'occur_time': '15:37:00'}},
#  {'_id': {'borough': 'MANHATTAN',
#    'occur_date': '2021-04-15T00:00:00.000',
#    'occur_time': '15:00:00'}}]

# %% [markdown]
# ### Summarize the total crimes happened in Brooklyn, Bronx, Queens, Manhattan, and Staten Island

# %%
from pprint import pprint
pipeline = [
    { "$match": { "boro": {"$in": ["BROOKLYN", "BRONX", "QUEENS","STATEN ISLAND", "MANHATTAN"]}} },
        { "$group":{ 
         "_id": {"borough": "$boro"},
        'count': { "$sum": 1 }}},
        { "$sort": {"count": 1} }
]

list(db.shooting.aggregate(pipeline))
# Out:
# [{'_id': {'borough': 'STATEN ISLAND'}, 'count': 40},
#  {'_id': {'borough': 'QUEENS'}, 'count': 296},
#  {'_id': {'borough': 'MANHATTAN'}, 'count': 343},
#  {'_id': {'borough': 'BROOKLYN'}, 'count': 631},
#  {'_id': {'borough': 'BRONX'}, 'count': 701}]

# %% [markdown]
# ## Technology 3:
# ## Elastic Search, Easy to scale (Distributed) Document-Oriented NoSQL Database

# %%
# !elasticsearch_loader --index shooting json shooting.json
# Out:
# {'index': 'shooting', 'bulk_size': 500, 'es_host': ('http://localhost:9200',), 'verify_certs': False, 'use_ssl': False, 'ca_certs': None, 'http_auth': None, 'delete': False, 'update': False, 'progress': False, 'type': '_doc', 'id_field': None, 'as_child': False, 'with_retry': False, 'index_settings_file': None, 'timeout': 10.0, 'encoding': 'utf-8', 'keys': [], 'es_conn': <Elasticsearch([{'host': 'localhost', 'port': 9200}])>}
# /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages/elasticsearch/connection/base.py:200: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
#   [####################################]

# %%
# !pip3 install elasticsearch
# !pip3 install elasticsearch-dsl
# Out:
# Requirement already satisfied: elasticsearch in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (7.17.1)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch) (1.26.7)
# Requirement already satisfied: certifi in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch) (2021.10.8)
# Requirement already satisfied: elasticsearch-dsl in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (7.4.0)
# Requirement already satisfied: elasticsearch<8.0.0,>=7.0.0 in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch-dsl) (7.17.1)
# Requirement already satisfied: six in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch-dsl) (1.16.0)
# Requirement already satisfied: python-dateutil in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch-dsl) (2.8.2)
# Requirement already satisfied: certifi in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (2021.10.8)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /Users/yongzeguan/opt/anaconda3/lib/python3.9/site-packages (from elasticsearch<8.0.0,>=7.0.0->elasticsearch-dsl) (1.26.7)

# %%
from elasticsearch_dsl import Search
from pprint import pprint
from elasticsearch_dsl import Q
from elasticsearch_dsl import connections
client = connections.create_connection(hosts=['localhost'],timeout=30)

# %%
#Most Recent Shooting
s = Search(using=client, index="shooting")[0] \
         .sort({'occur_date': {'order': 'desc'}})#asc

response = s.execute()

for hit in response['hits']['hits']:
    pprint(hit['_source'].to_dict())
# Out:
# {':@computed_region_92fq_4b7q': '13',
#  ':@computed_region_efsh_h5xi': '10692',
#  ':@computed_region_f5dn_yrer': '4',
#  ':@computed_region_sbqj_enih': '74',
#  ':@computed_region_yeji_bk3q': '1',
#  'boro': 'STATEN ISLAND',
#  'geocoded_column': {'coordinates': [-74.06527594399995, 40.61293530900008],
#                      'type': 'Point'},
#  'incident_key': '238490103',
#  'jurisdiction_code': '0',
#  'latitude': '40.61293530900008',
#  'location_desc': 'PVT HOUSE',
#  'longitude': '-74.06527594399995',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '19:23:00',
#  'perp_age_group': '45-64',
#  'perp_race': 'WHITE',
#  'perp_sex': 'M',
#  'precinct': '120',
#  'statistical_murder_flag': True,
#  'vic_age_group': '25-44',
#  'vic_race': 'WHITE',
#  'vic_sex': 'M',
#  'x_coord_cd': '966127',
#  'y_coord_cd': '162589'}

# %%
#Example of shooting at Brooklyn in Desending Order
#Other borough can be refer with same method but different query name
s = Search(using=client, index="shooting")\
    .query("match", boro="BROOKLYN")\
    .sort({'occur_date': {'order': 'desc'}})
response = s.execute() # by default you get 10 hits

for hit in response['hits']['hits']:
    pprint(hit['_source'].to_dict())
# Out:
# {':@computed_region_92fq_4b7q': '25',
#  ':@computed_region_efsh_h5xi': '17214',
#  ':@computed_region_f5dn_yrer': '45',
#  ':@computed_region_sbqj_enih': '47',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.88509115599999, 40.65690638000007],
#                      'type': 'Point'},
#  'incident_key': '238487793',
#  'jurisdiction_code': '2',
#  'latitude': '40.65690638000007',
#  'location_desc': 'MULTI DWELL - PUBLIC HOUS',
#  'longitude': '-73.88509115599999',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '15:36:00',
#  'precinct': '75',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '1016133',
#  'y_coord_cd': '178623'}
# {':@computed_region_92fq_4b7q': '11',
#  ':@computed_region_efsh_h5xi': '13510',
#  ':@computed_region_f5dn_yrer': '60',
#  ':@computed_region_sbqj_enih': '43',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.95969593099994, 40.64597209200008],
#                      'type': 'Point'},
#  'incident_key': '238481445',
#  'jurisdiction_code': '0',
#  'latitude': '40.64597209200008',
#  'longitude': '-73.95969593099994',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '04:25:00',
#  'precinct': '70',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '995435',
#  'y_coord_cd': '174621'}
# {':@computed_region_92fq_4b7q': '25',
#  ':@computed_region_efsh_h5xi': '17214',
#  ':@computed_region_f5dn_yrer': '45',
#  ':@computed_region_sbqj_enih': '47',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.88509115599999, 40.65690638000007],
#                      'type': 'Point'},
#  'incident_key': '238487793',
#  'jurisdiction_code': '2',
#  'latitude': '40.65690638000007',
#  'location_desc': 'MULTI DWELL - PUBLIC HOUS',
#  'longitude': '-73.88509115599999',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '15:36:00',
#  'precinct': '75',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '1016133',
#  'y_coord_cd': '178623'}
# {':@computed_region_92fq_4b7q': '11',
#  ':@computed_region_efsh_h5xi': '13510',
#  ':@computed_region_f5dn_yrer': '60',
#  ':@computed_region_sbqj_enih': '43',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.95969593099994, 40.64597209200008],
#                      'type': 'Point'},
#  'incident_key': '238481445',
#  'jurisdiction_code': '0',
#  'latitude': '40.64597209200008',
#  'longitude': '-73.95969593099994',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '04:25:00',
#  'precinct': '70',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '995435',
#  'y_coord_cd': '174621'}
# {':@computed_region_92fq_4b7q': '25',
#  ':@computed_region_efsh_h5xi': '17214',
#  ':@computed_region_f5dn_yrer': '45',
#  ':@computed_region_sbqj_enih': '47',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.88509115599999, 40.65690638000007],
#                      'type': 'Point'},
#  'incident_key': '238487793',
#  'jurisdiction_code': '2',
#  'latitude': '40.65690638000007',
#  'location_desc': 'MULTI DWELL - PUBLIC HOUS',
#  'longitude': '-73.88509115599999',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '15:36:00',
#  'precinct': '75',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '1016133',
#  'y_coord_cd': '178623'}
# {':@computed_region_92fq_4b7q': '11',
#  ':@computed_region_efsh_h5xi': '13510',
#  ':@computed_region_f5dn_yrer': '60',
#  ':@computed_region_sbqj_enih': '43',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.95969593099994, 40.64597209200008],
#                      'type': 'Point'},
#  'incident_key': '238481445',
#  'jurisdiction_code': '0',
#  'latitude': '40.64597209200008',
#  'longitude': '-73.95969593099994',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '04:25:00',
#  'precinct': '70',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '995435',
#  'y_coord_cd': '174621'}
# {':@computed_region_92fq_4b7q': '25',
#  ':@computed_region_efsh_h5xi': '17214',
#  ':@computed_region_f5dn_yrer': '45',
#  ':@computed_region_sbqj_enih': '47',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.88509115599999, 40.65690638000007],
#                      'type': 'Point'},
#  'incident_key': '238487793',
#  'jurisdiction_code': '2',
#  'latitude': '40.65690638000007',
#  'location_desc': 'MULTI DWELL - PUBLIC HOUS',
#  'longitude': '-73.88509115599999',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '15:36:00',
#  'precinct': '75',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '1016133',
#  'y_coord_cd': '178623'}
# {':@computed_region_92fq_4b7q': '11',
#  ':@computed_region_efsh_h5xi': '13510',
#  ':@computed_region_f5dn_yrer': '60',
#  ':@computed_region_sbqj_enih': '43',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.95969593099994, 40.64597209200008],
#                      'type': 'Point'},
#  'incident_key': '238481445',
#  'jurisdiction_code': '0',
#  'latitude': '40.64597209200008',
#  'longitude': '-73.95969593099994',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '04:25:00',
#  'precinct': '70',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '995435',
#  'y_coord_cd': '174621'}
# {':@computed_region_92fq_4b7q': '25',
#  ':@computed_region_efsh_h5xi': '17214',
#  ':@computed_region_f5dn_yrer': '45',
#  ':@computed_region_sbqj_enih': '47',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.88509115599999, 40.65690638000007],
#                      'type': 'Point'},
#  'incident_key': '238487793',
#  'jurisdiction_code': '2',
#  'latitude': '40.65690638000007',
#  'location_desc': 'MULTI DWELL - PUBLIC HOUS',
#  'longitude': '-73.88509115599999',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '15:36:00',
#  'precinct': '75',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '1016133',
#  'y_coord_cd': '178623'}
# {':@computed_region_92fq_4b7q': '11',
#  ':@computed_region_efsh_h5xi': '13510',
#  ':@computed_region_f5dn_yrer': '60',
#  ':@computed_region_sbqj_enih': '43',
#  ':@computed_region_yeji_bk3q': '2',
#  'boro': 'BROOKLYN',
#  'geocoded_column': {'coordinates': [-73.95969593099994, 40.64597209200008],
#                      'type': 'Point'},
#  'incident_key': '238481445',
#  'jurisdiction_code': '0',
#  'latitude': '40.64597209200008',
#  'longitude': '-73.95969593099994',
#  'occur_date': '2021-12-31T00:00:00.000',
#  'occur_time': '04:25:00',
#  'precinct': '70',
#  'statistical_murder_flag': False,
#  'vic_age_group': '25-44',
#  'vic_race': 'BLACK',
#  'vic_sex': 'M',
#  'x_coord_cd': '995435',
#  'y_coord_cd': '174621'}
